# %%
# Ubisoft creepy.log Analysis
## Stephane Gosselin

# %%
import numpy as np
import pandas as pd
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
pd.set_option('display.max_columns', 500)
# %matplotlib notebook

data = pd.read_csv('./creepy.csv')

# %%
# Understanding the Game
## Statistics of players at last event

df = data

new = df[['player_strength','player_wisdom','player_gold','player_xp','player_id']].groupby('player_id')['player_strength','player_wisdom','player_gold','player_xp'].max()

g = sns.pairplot(new, diag_kind='kde', size=2)
g.set(yticks=[],xticks=[])
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
